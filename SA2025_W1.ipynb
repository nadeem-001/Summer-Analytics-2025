# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
df = pd.read_csv("Cars.csv")

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
print(df.shape)
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
print(df)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
df.set_index('name', inplace=True)

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
unique_mpg = df['mpg'].unique()
print(unique_mpg)
# Out:
# [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
df['hp_per_weight'] = df['horsepower'] / df['weight']
df.set_index('hp_per_weight', inplace=True)

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
max_hp_car = df.loc[df["horsepower"].idxmax()]
print(f"Name: {max_hp_car['name']}\nHorsepower: {max_hp_car['horsepower']}")
# Out:
# Name: pontiac grand prix
# Horsepower: 230.0

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
print(f"Number of cars with mpg > 35: {high_mpg_count}")
# Out:
# Number of cars with mpg > 35: 33

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
 

df["horsepower"] = pd.to_numeric(df["horsepower"])
df["weight"] = pd.to_numeric(df["weight"], errors="coerce")

filtered_cars = df[(df["horsepower"] > 100) & (df["weight"] < 3000)]

most_common_origin = filtered_cars["origin"].value_counts().idxmax()

print(f"Most common origin for cars with horsepower > 100 and weight < 3000: {most_common_origin}")
# Out:
# Most common origin for cars with horsepower > 100 and weight < 3000: usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
df["acceleration"] = pd.to_numeric(df["acceleration"])

mean_acceleration = df[df["origin"] == "japan"]["acceleration"].mean()
print(f"Mean acceleration of Japanese cars: {round(mean_acceleration, 2)} seconds")
# Out:
# Mean acceleration of Japanese cars: 16.17 seconds

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
df["mpg"] = pd.to_numeric(df["mpg"])
df["model_year"] = pd.to_numeric(df["model_year"])
avg_mpg_by_year = df.groupby("model_year")["mpg"].mean()

highest_avg_mpg_year = avg_mpg_by_year.idxmax()
highest_avg_mpg_value = round(avg_mpg_by_year.max(), 1)

print(f"Year with highest average mpg: {highest_avg_mpg_year} ({highest_avg_mpg_value} mpg)")
# Out:
# Year with highest average mpg: 80 (33.8 mpg)

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
df["horsepower"] = pd.to_numeric(df["horsepower"], errors="coerce")
df["weight"] = pd.to_numeric(df["weight"], errors="coerce")
df["mpg"] = pd.to_numeric(df["mpg"], errors="coerce")

df["hp_weight_ratio"] = df["horsepower"] / df["weight"]

median_mpg = df["mpg"].median()
filtered_df = df[df["mpg"] > median_mpg]

best_ratio_car = filtered_df.loc[filtered_df["hp_weight_ratio"].idxmax()]

print(f"Car with the best horsepower-to-weight ratio among high-mpg cars:\n"
      f"Name: {best_ratio_car['name']}\n"
      f"Ratio: {best_ratio_car['hp_weight_ratio']:.5f}")
# Out:
# Car with the best horsepower-to-weight ratio among high-mpg cars:
# Name: bmw 2002
# Ratio: 0.05058

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here
df["mpg"] = pd.to_numeric(df["mpg"], errors="coerce")
df["model_year"] = pd.to_numeric(df["model_year"], errors="coerce")

avg_mpg_by_year = df.groupby(["model_year", "origin"])["mpg"].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_mpg_by_year, x="model_year", y="mpg", hue="origin", marker="o")
plt.title("Evolution of Average MPG Over Years by Origin")
plt.xlabel("Model Year")
plt.ylabel("Average MPG")
plt.legend(title="Origin")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
df["horsepower"] = pd.to_numeric(df["horsepower"], errors="coerce")
df["weight"] = pd.to_numeric(df["weight"], errors="coerce")
df["mpg"] = pd.to_numeric(df["mpg"], errors="coerce")

plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x="horsepower",
    y="weight",
    hue="origin",
    size="mpg",
    palette="coolwarm",
    hue_order=['japan', 'europe', 'usa'],
    sizes=(20, 200)
)
plt.title("Horsepower vs. Weight of Cars, Colored by Origin and Sized by MPG")
plt.xlabel("Horsepower")
plt.ylabel("Weight (lbs)")
plt.legend(title="Origin")
plt.grid(True)

plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here
df["mpg"] = pd.to_numeric(df["mpg"], errors="coerce")

model_counts = df["name"].value_counts()
multi_year_models = model_counts[model_counts > 1].index

std_mpg = df[df["name"].isin(multi_year_models)].groupby("name")["mpg"].std()

consistent_models = std_mpg[std_mpg < 1.0].index

final_df = df[df["name"].isin(consistent_models)].groupby("name").agg(
    appearances=("name", "count"),
    avg_mpg=("mpg", "mean")
).reset_index()

final_df = final_df.sort_values(by=["appearances", "avg_mpg"], ascending=[False, False])

print(final_df)
# Out:
#                          name  appearances    avg_mpg
# 4            ford galaxie 500            3  14.333333
# 8           plymouth fury iii            3  14.333333
# 10        toyota corolla 1200            2  31.500000
# 7                   mazda 626            2  31.450000
# 12          volkswagen rabbit            2  29.250000
# 2                datsun pl510            2  27.000000
# 9                   saab 99le            2  24.500000
# 11             toyota mark ii            2  19.500000
# 3                 dodge aspen            2  18.850000
# 1   chevrolet chevelle malibu            2  17.500000
# 0            amc matador (sw)            2  14.500000
# 5       ford gran torino (sw)            2  13.500000
# 6                    ford ltd            2  13.500000

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
